# %%
import pyttsx3
import speech_recognition as sr 
import datetime
import wikipedia 
import webbrowser
import os
import smtplib

engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[0].id)


def speak(audio):
    engine.say(audio)
    engine.runAndWait()


def wishMe():
    hour = int(datetime.datetime.now().hour)
    
    if hour>=0 and hour<12:
        speak("Good Morning! Hacker")

    elif hour>=12 and hour<18:
        speak("Good Afternoon! Hacker")   

    else:
        speak("Good Evening! Hacker")  

    speak("I am Jarvis. Please tell me how may I help you")       

def takeCommand():
    #It takes microphone input from the user and returns string output

    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        r.pause_threshold = 1
        audio = r.listen(source)

    try:
        print("Recognizing...")    
        query = r.recognize_google(audio, language='en-in')
        print(f"User said: {query}\n")

    except Exception as e:
        # print(e)    
        print("Say that again please...")  
        return "None"
    
    return query

def sendEmail(to, content):
    server = smtplib.SMTP('smtp.gmail.com', 587)
    server.ehlo()
    server.starttls()
    server.login('vermaanshul178@gmail.com', 'vermaanshul178')
    server.sendmail('vermaanshul178@gmail.com', to, content)
    server.close()

if __name__ == "__main__":
    wishMe()
    while True:
    # if 1:
        query = takeCommand().lower()

        # Logic for executing tasks based on query
        if 'wikipedia' in query:
            speak('Searching Wikipedia...')
            query = query.replace("wikipedia", "")
            try:    
                results = wikipedia.summary(query, sentences=3)
                speak("According to Wikipedia")
                print(results)
                speak(results)
            
            except:
                speak("Not Found On Wikipedia, Try Again")
                print("Not Found On Wikipedia, Try Again")
                query = takeCommand().lower()
        
        elif "what can you do for me" in query or "operations can you do for me" in query or "display the functions" in query or "what can you do" in query or "list all the functions" in query:
            speak("Listing The Operations which I can Perform.")
            print("1.Google Chrome\n2.Internet Explorer\n3.Microsoft Edge\n4.Mozilla Firefox\n5.Notepad\n6.Notepad++\n7.Windows Media Player\n8.VLC Media Player\n9.Command Prompt\n10.Calculations\n11.Paint\n12.File Explorer\n13.Camera\n14.Facebook\n15.Send Whatsapp Messages Directly\n16.Video Songs\n17.Open Github\n18.Send Email\n19.Send SMS\n20.Youtube\n21.Wikipedia Searches\n22.Open GMail\n23.Open Linkedin Profile\n24.Open Github Profile\n25.Open Stack Overflow\n26.Open Whatsapp Web\n27.OPen Instagarm\n28.Shutdown PC\n.29.Restart PC") 
            speak("Thats All Sir.") 
            
        elif "dont" in query or "don't" in query or "do not" in query :
            print("Ok Sir, I Will Not Perform The Following Task..")
            speak("Ok Sir, I Will Not Perform The Following Task..")

        elif 'the time' in query:
            strTime = datetime.datetime.now().strftime("%H:%M:%S")    
            speak(f"Sir, the time is {strTime}")
        
        elif 'open youtube' in query:
            webbrowser.open("youtube.com")

        elif 'open google' in query:
            webbrowser.open("google.com")

        elif 'open stack overflow' in query:
            webbrowser.open("stackoverflow.com")
            
        elif "open facebook" in query:
            webbrowser.open("facebook.com")
            
        elif "open whatsapp" in query:
            webbrowser.open("https://web.whatsapp.com/")
            
        elif "open instagram" in query:
            webbrowser.open("https://www.instagram.com/")
            
        elif "send whatsapp message" in query:
            from twilio.rest import Client
            account = "AC3e6f9ed69ec0b63d05d7dd15bdf622cb"
            token = "c2fb510084c0c91baa3f576aa65c88df"
            client = Client(account, token)
            speak("What should I say?")
            content = takeCommand()
            message = client.messages.create(to="whatsapp:+917844071513", from_="whatsapp:+14155238886",body=content)
            print (message.sid)
            
        elif "open linkedin" in query:
            webbrowser.open("https://www.linkedin.com/feed/")
            
        elif "open github" in query:
            webbrowser.open("https://github.com/Anshul-Hacker")
            
        elif "open gmail" in query:
            webbrowser.open("https://mail.google.com/mail/u/0/#inbox")
        
        elif 'send email' in query:
            try:
                speak("What should I say?")
                content = takeCommand()
                to = "tigeranshul321@gmail.com"    
                sendEmail(to, content)
                speak("Email has been sent!")
            except Exception as e:
                print(e)
                speak("Sorry Sir. I am not able to send this email due to server problem.")
                
        elif "send sms" in query or " send text message" in query :
            from twilio.rest import Client
            # Your Account Sid and Auth Token from twilio.com/console
            # and set the environment variables. See http://twil.io/secure
            account_sid = 'AC3e6f9ed69ec0b63d05d7dd15bdf622cb'
            auth_token = 'c2fb510084c0c91baa3f576aa65c88df'
            client = Client(account_sid, auth_token)
            speak("What should I say?")
            content = takeCommand()
            message = client.messages.create(body=content,from_='+17692074175',to='+917844071513')
            print(message.sid)

        elif 'play music' in query or 'play songs' in query:
            music_dir = 'E:\Video song'
            songs = os.listdir(music_dir)
            print(songs)    
            os.startfile(os.path.join(music_dir, songs[0]))
        
        elif "good text editor" in query or "high level text editor" in query or "external text editor" in query or "notepad plus plus" in query :
            speak("Opening Notepad++")
            os.system("notepad++")
        
        elif "chrome" in query or "web" in query or "browser" in query or "google" in query:
            speak("Opening Google Chrome")
            os.system("chrome")
            
        elif "internet explorer" in query or "internet" in query or "explorer" in query:
            speak("Opening Internet Explorer")
            os.system("iexplore")
                
        elif "mozilla" in query or "firefox" in query or "mozilla internet" in query:
            speak("Opening Mozilla Firefox")
            os.system("firefox")        
        
        elif "notepad" in query or "text" in query or "editor" in query:
            speak("Opening Notepad")
            os.system("notepad")        
        
        elif "good media player" in query or "external player" in query or "vlc" in query or "good player" in query:
            speak("Opening VLC Media Player")
            os.system("vlc")        
   
        elif "media player" in query or "video player" in query or "player" in query:
            speak("Opening Windows Media Player")
            os.system("wmplayer")
               
        elif "microsoft" in query or "edge" in query:
            speak("Opening Microsoft Edge")
            os.system("msedge")
               
        elif "camera" in query or "webcam" in query or "take selfie" in query:
            speak("Opening Camera")
            os.system("YouCam9")    
    
        elif "calci" in query or "calculator" in query or "calculate" in query or "perform calculations" in query :
            speak("Opening Calculator")
            os.system("calc")       
    
        elif "paint" in query or "draw" in query or "mspaint" in query :
            speak("Opening Paint")
            os.system("mspaint")       
        
        elif "cmd" in query or "prompt" in query or "command prompt" in query :
            speak("Opening Command Prompt")
            os.system("cmd")       
        
        elif "file" in query or "manager" in query or "this pc" in query or "pc" in query:
            speak("Opening File Explorer")
            os.system("explorer")    
        
        elif "stop" in query or "exit" in query or "quit" in query or "nothing" in query:
            print("Thanks For The Interaction Sir....\n:)")
            speak("Thanks For The Interaction Sir....\n:)")
            break
            
        elif "shut down" in query or "shutdown" in query or "power off" in query :
            os.system("shutdown /s /t 2")
            
        elif "restart" in query :
            os.system("shutdown /r /t 2")
            
        else:
            continue
# Out:
# Listening...
# Recognizing...
# User said: India on Wikipedia
#
# India (Hindi: Bhārat), officially the Republic of India (Hindi: Bhārat Gaṇarājya), is a country in South Asia. It is the second-most populous country, the seventh-largest country by land area, and the most populous democracy in the world.  Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west; China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east.
# Listening...
# Recognizing...
# User said: exit
#
# Thanks For The Interaction Sir....
# :)
